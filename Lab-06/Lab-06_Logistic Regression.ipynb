# %% [markdown]
# # Lab-06 Logistic Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn
# %matplotlib inline

# %%
df = pd.read_csv('marital status.csv')

# %%
df
# Out:
#    age marital_status
# 0   25         Single
# 1   30        Married
# 2  NaN         Single
# 3   45       Divorced
# 4   35        Married
# 5   28         Single
# 6   40            NaN
# 7   55       Divorced
# 8    ,        Married
# 9   27         Single

# %% [markdown]
# ## Checking Null/Nan Values

# %%
df.isnull().sum()
# Out:
# age               1
# marital_status    1
# dtype: int64

# %%
df = pd.read_csv('marital status_Log_Reg.csv')

# %%
df
# Out:
#     age  marital_status
# 0    25               0
# 1    30               1
# 2    60               0
# 3    45               1
# 4    35               1
# 5    28               0
# 6    40               1
# 7    55               1
# 8    37               1
# 9    27               0
# 10   26               0
# 11   32               1
# 12   35               0
# 13   47               1
# 14   37               1
# 15   29               0
# 16   41               1
# 17   53               1
# 18   45               1
# 19   25               0

# %%
df.isnull().sum()
# Out:
# age               0
# marital_status    0
# dtype: int64

# %% [markdown]
# ## Filling null values of age column

# %%
updated_df = df
updated_df['age']=updated_df['age'].fillna(updated_df['age'].mean())
updated_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             20 non-null     int64
#  1   marital_status  20 non-null     int64
# dtypes: int64(2)
# memory usage: 452.0 bytes

# %%
handle = df['marital_status'].median()

# %%
handle
# Out:
# np.float64(1.0)

# %% [markdown]
# ## filling null values with median means handle

# %%
df.marital_status= df.marital_status.fillna(handle)
